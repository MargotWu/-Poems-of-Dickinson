# %% [markdown]
# Introduction
#
# This corpus contains five representative poems by Dickinson. I will use spacy to analyze the parts of speech in these five poems and explore the common images and the topics they represent in Dickinson's poems.

# %% [markdown]
# Research Questions
#
# What are the main images in Dickinson's poetry?
# In relation to specific texts, what themes does Dickinson typically use these images to express?

# %% [markdown]
# Installing, Importing and Preprocessing

# %%
pip install nbformat --upgrade
# Out:
# Requirement already satisfied: nbformat in /Users/margotwu/anaconda3/lib/python3.11/site-packages (5.9.2)
# Requirement already satisfied: fastjsonschema in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from nbformat) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from nbformat) (4.17.3)
# Requirement already satisfied: jupyter-core in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from nbformat) (5.3.0)
# Requirement already satisfied: traitlets>=5.1 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from nbformat) (5.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from jupyter-core->nbformat) (2.5.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install and import spacy and plotly.
# %pip install spaCy
# %pip install plotly
# Out:
# Requirement already satisfied: spaCy in /Users/margotwu/anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (2.5.2)
# Requirement already satisfied: jinja2 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (3.1.2)
# Requirement already satisfied: setuptools in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spaCy) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spaCy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spaCy) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spaCy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spaCy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spaCy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spaCy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spaCy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spaCy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spaCy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spaCy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spaCy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from jinja2->spaCy) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: plotly in /Users/margotwu/anaconda3/lib/python3.11/site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from plotly) (8.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import spacy
import spacy

# Install English language model
# !spacy download en_core_web_sm

# Import os to upload documents and metadata
import os

# Load spaCy visualizer
from spacy import displacy

# Import pandas DataFrame packages
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# Import graphing package
import plotly.graph_objects as go
import plotly.express as px
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 18.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.2)
# Requirement already satisfied: jinja2 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/margotwu/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Create empty lists for file names and contents
texts = []
file_names = []

# Iterate through each file in the folder
for _file_name in os.listdir('txt_files'):
# Look for only text files
    if _file_name.endswith('.txt'):
    # Append contents of each text file to text list
        texts.append(open('txt_files' + '/' + _file_name, 'r', encoding='utf-8').read())
        # Append name of each file to file name list
        file_names.append(_file_name)

# %%
# Create dictionary object associating each file name with its text
d = {'Filename':file_names,'Text':texts}

# %%
# Turn dictionary into a dataframe
poems_df = pd.DataFrame(d)

# %%
poems_df.head()
# Out:
#                                  Filename  \
# 0                  I never saw a Moor.txt
# 1                    I keep my pledge.txt
# 2  Because I could not stop for Death.txt
# 3               After A Hundred Years.txt
# 4              Had I not seen the Sun.txt
#
#                                                 Text
# 0  ﻿I never saw a Moor\nI never saw a Moor--\nI n...
# 1  ﻿I keep my pledge\nI was not called -\nDeath d...
# 2  ﻿Because I could not stop for Death \n\nHe kin...
# 3  ﻿After A Hundred Years\n\nAfter a hundred year...
# 4  ﻿Had I not seen the Sun\n\nHad I not seen the ...

# %%
# Remove extra spaces from papers
paper_df['Text'] = paper_df['Text'].str.replace('\s+', ' ', regex=True).str.strip()
paper_df.head()
# Out:
#                              Filename  \
# 0                  I never saw a Moor
# 1                    I keep my pledge
# 2  Because I could not stop for Death
# 3               After A Hundred Years
# 4              Had I not seen the Sun
#
#                                                 Text
# 0  ﻿I never saw a Moor I never saw a Moor-- I nev...
# 1  ﻿I keep my pledge I was not called - Death did...
# 2  ﻿Because I could not stop for Death He kindly ...
# 3  ﻿After A Hundred Years After a hundred years N...
# 4  ﻿Had I not seen the Sun Had I not seen the sun...

# %%
# Remove .txt from title of each paper
poems_df['Filename'] = poems_df['Filename'].str.replace('.txt', '', regex=True)

# %%
# Print DataFrame
poems_df.head()
# Out:
#                              Filename  \
# 0                  I never saw a Moor
# 1                    I keep my pledge
# 2  Because I could not stop for Death
# 3               After A Hundred Years
# 4              Had I not seen the Sun
#
#                                                 Text
# 0  ﻿I never saw a Moor\nI never saw a Moor--\nI n...
# 1  ﻿I keep my pledge\nI was not called -\nDeath d...
# 2  ﻿Because I could not stop for Death \n\nHe kin...
# 3  ﻿After A Hundred Years\n\nAfter a hundred year...
# 4  ﻿Had I not seen the Sun\n\nHad I not seen the ...

# %% [markdown]
# Tokenization

# %%
# Load nlp pipeline
nlp = spacy.load('en_core_web_sm')

# Check what functions it performs
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
#Define example sentence
sentence = "This is 'an' example? sentence"

# Call the nlp model on the sentence
doc = nlp(sentence)

# %%
# Loop through each token in doc object
for token in doc:
    # Print text and part of speech for each
    print(token.text, token.pos_)
# Out:
# This PRON
# is AUX
# ' PUNCT
# an DET
# ' PUNCT
# example NOUN
# ? PUNCT
# sentence NOUN

# %%
# Define a function that runs the nlp pipeline on any given input text
def process_text(text):
    return nlp(text)

# %%
# Apply the function to the "Text" column, so that the nlp pipeline is called on each poem
poems_df['Doc'] = poems_df['Text'].apply(process_text)

# %%
# Define a function to retrieve tokens from a doc object
def get_token(doc):
    return [(token.text) for token in doc]

# %%
# Run the token retrieval function on the doc objects in the dataframe
poems_df['Tokens'] = poems_df['Doc'].apply(get_token)
poems_df.head()
# Out:
#                              Filename  \
# 0                  I never saw a Moor
# 1                    I keep my pledge
# 2  Because I could not stop for Death
# 3               After A Hundred Years
# 4              Had I not seen the Sun
#
#                                                 Text  \
# 0  ﻿I never saw a Moor\nI never saw a Moor--\nI n...
# 1  ﻿I keep my pledge\nI was not called -\nDeath d...
# 2  ﻿Because I could not stop for Death \n\nHe kin...
# 3  ﻿After A Hundred Years\n\nAfter a hundred year...
# 4  ﻿Had I not seen the Sun\n\nHad I not seen the ...
#
#                                                  Doc  \
# 0  (﻿I, never, saw, a, Moor, \n, I, never, saw, a...
# 1  (﻿I, keep, my, pledge, \n, I, was, not, called...
# 2  (﻿Because, I, could, not, stop, for, Death, \n...
# 3  (﻿After, A, Hundred, Years, \n\n, After, a, hu...
# 4  (﻿Had, I, not, seen, the, Sun, \n\n, Had, I, n...
#
#                                               Tokens
# 0  [﻿I, never, saw, a, Moor, \n, I, never, saw, a...
# 1  [﻿I, keep, my, pledge, \n, I, was, not, called...
# 2  [﻿Because, I, could, not, stop, for, Death, \n...
# 3  [﻿After, A, Hundred, Years, \n\n, After, a, hu...
# 4  [﻿Had, I, not, seen, the, Sun, \n\n, Had, I, n...

# %%
tokens = poems_df[['Text', 'Tokens']].copy()
tokens.head()
# Out:
#                                                 Text  \
# 0  ﻿I never saw a Moor\nI never saw a Moor--\nI n...
# 1  ﻿I keep my pledge\nI was not called -\nDeath d...
# 2  ﻿Because I could not stop for Death \n\nHe kin...
# 3  ﻿After A Hundred Years\n\nAfter a hundred year...
# 4  ﻿Had I not seen the Sun\n\nHad I not seen the ...
#
#                                               Tokens
# 0  [﻿I, never, saw, a, Moor, \n, I, never, saw, a...
# 1  [﻿I, keep, my, pledge, \n, I, was, not, called...
# 2  [﻿Because, I, could, not, stop, for, Death, \n...
# 3  [﻿After, A, Hundred, Years, \n\n, After, a, hu...
# 4  [﻿Had, I, not, seen, the, Sun, \n\n, Had, I, n...

# %% [markdown]
# Lemmatization

# %%
# Define a function to retrieve lemmas from a doc object
def get_lemma(doc):
    return [(token.lemma_) for token in doc]

# Run the lemma retrieval function on the doc objects in the dataframe
poems_df['Lemmas'] = poems_df['Doc'].apply(get_lemma)

# %% [markdown]
# Part of Speech Analysis

# %%
# Define a function to retrieve lemmas from a doc object
def get_pos(doc):
    #Return the coarse- and fine-grained part of speech text for each token in the doc
    return [(token.pos_, token.tag_) for token in doc]

# Define a function to retrieve parts of speech from a doc object
poems_df['POS'] = poems_df['Doc'].apply(get_pos)

# %%
# Create a list of part of speech tags
list(poems_df['POS'])
# Out:
# [[('PROPN', 'NNP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SPACE', '_SP'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBZ'),
#   ('SPACE', '_SP'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'WP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VB'),
#   ('PUNCT', '.'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('SPACE', '_SP'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('NUM', 'CD'),
#   ('SPACE', '_SP'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('AUX', 'VBP'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SPACE', '_SP'),
#   ('SCONJ', 'IN'),
#   ('SCONJ', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNPS'),
#   ('AUX', 'VBD'),
#   ('PROPN', 'NNP'),
#   ('SPACE', '_SP')],
#  [('NOUN', 'NN'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VBN'),
#   ('PUNCT', 'HYPH'),
#   ('SPACE', '_SP'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '.'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP$'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('SPACE', '_SP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('SPACE', '_SP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('SPACE', '_SP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('SPACE', '_SP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('PUNCT', 'HYPH'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP'),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('PUNCT', '.'),
#   ('SPACE', '_SP')],
#  [('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBD'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBD'),
#   ('PUNCT', ':'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SPACE', '_SP'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBN'),
#   ('ADV', 'RB'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('SPACE', '_SP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('SCONJ', 'WRB'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('SPACE', '_SP'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNPS'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('VERB', 'VBG'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('PUNCT', ':'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNPS'),
#   ('VERB', 'VBD'),
#   ('VERB', 'VBG'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP'),
#   ('ADP', 'IN'),
#   ('ADV', 'RB'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('ADV', 'RB'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'WDT'),
#   ('VERB', 'VBD'),
#   ('SPACE', '_SP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VBD'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ':'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP'),
#   ('SCONJ', 'IN'),
#   ('ADV', 'RB'),
#   ('PUNCT', ':'),
#   ('PUNCT', '``'),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNPS'),
#   ('PUNCT', ':'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('SPACE', '_SP'),
#   ('VERB', 'VBZ'),
#   ('ADJ', 'JJR'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNPS'),
#   ('PART', 'POS'),
#   ('NOUN', 'NNS'),
#   ('SPACE', '_SP'),
#   ('AUX', 'VBD'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP')],
#  [('PUNCT', '.'),
#   ('DET', 'DT'),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNPS'),
#   ('SPACE', '_SP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NUM', 'CD'),
#   ('NOUN', 'NNS'),
#   ('SPACE', '_SP'),
#   ('PRON', 'NN'),
#   ('VERB', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PRON', 'WDT'),
#   ('VERB', 'VBN'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('SPACE', '_SP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('SPACE', '_SP'),
#   ('NOUN', 'NNS'),
#   ('ADJ', 'JJ'),
#   ('VERB', 'VBN'),
#   ('PUNCT', ','),
#   ('SPACE', '_SP'),
#   ('PROPN', 'NNPS'),
#   ('VERB', 'VBD'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBN'),
#   ('SPACE', '_SP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('SPACE', '_SP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJR'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('SPACE', '_SP'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('SPACE', '_SP'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PUNCT', ':'),
#   ('SPACE', '_SP'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBG'),
#   ('ADP', 'RP'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('SPACE', '_SP'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('SPACE', '_SP')],
#  [('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('PART', 'RB'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('SPACE', '_SP'),
#   ('AUX', 'VBD'),
#   ('PRON', 'PRP'),
#   ('PART', 'RB'),
#   ('VERB', 'VBN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SPACE', '_SP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJR'),
#   ('NOUN', 'NN'),
#   ('SPACE', '_SP'),
#   ('PRON', 'PRP$'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VBZ'),
#   ('VERB', 'VBN'),
#   ('SPACE', '_SP')]]

# %%
spacy.explain("IN")
# Out:
# 'conjunction, subordinating or preposition'

# %%
# Define function to extract proper nouns from Doc object
def extract_proper_nouns(doc):
    return [token.text for token in doc if token.pos_ == 'PROPN']

# Apply function to Doc column and store resulting proper nouns in new column
poems_df['Proper_Nouns'] = poems_df['Doc'].apply(extract_proper_nouns)

# %%
# Create doc object from single sentence
doc = nlp("This is 'an' example? sentence")

# Print counts of each part of speech in sentence
print(doc.count_by(spacy.attrs.POS))
# Out:
# {95: 1, 87: 1, 97: 3, 90: 1, 92: 2}

# %%
# Store dictionary with indexes and POS counts in a variable
num_pos = doc.count_by(spacy.attrs.POS)

dictionary = {}

# Create a new dictionary which replaces the index of each part of speech for its label (NOUN, VERB, ADJECTIVE)
for k,v in sorted(num_pos.items()):
  dictionary[doc.vocab[k].text] = v

dictionary
# Out:
# {'AUX': 1, 'DET': 1, 'NOUN': 2, 'PRON': 1, 'PUNCT': 3}

# %%
# Create new DataFrame for analysis purposes
pos_analysis_df = poems_df[['Filename', 'Text','Doc']]

# Create list to store each dictionary
num_list = []

# Define a function to get part of speech tags and counts and append them to a new dictionary
def get_pos_tags(doc):
    dictionary = {}
    num_pos = doc.count_by(spacy.attrs.POS)
    for k,v in sorted(num_pos.items()):
        dictionary[doc.vocab[k].text] = v
    num_list.append(dictionary)

# Apply function to each doc object in DataFrame
pos_analysis_df.loc['C_POS'] = pos_analysis_df['Doc'].apply(get_pos_tags)

# %%
# Create new dataframe with part of speech counts
pos_counts = pd.DataFrame(num_list)
columns = list(pos_counts.columns)

# Add Text of each poem as new column to dataframe
idx = 0
new_col = pos_analysis_df['Text']
pos_counts.insert(loc=idx, column='Text', value=new_col)

pos_counts
# Out:
#                                                 Text  ADJ   ADP   ADV  AUX  \
# 0  ﻿I never saw a Moor\nI never saw a Moor--\nI n...    1   3.0   4.0  3.0
# 1  ﻿I keep my pledge\nI was not called -\nDeath d...    1   5.0   3.0  3.0
# 2  ﻿Because I could not stop for Death \n\nHe kin...    2  12.0  12.0  4.0
# 3  ﻿After A Hundred Years\n\nAfter a hundred year...    3   7.0   1.0  NaN
# 4  ﻿Had I not seen the Sun\n\nHad I not seen the ...    1   NaN   NaN  4.0
#
#    CCONJ  DET  NOUN  NUM  PRON  PROPN  PUNCT  SCONJ  VERB  SPACE  PART
# 0      4    7     3  1.0     6      7    1.0    3.0     7      9   NaN
# 1      2    1     7  NaN     8      5   11.0    NaN     7     11   2.0
# 2      7   15    12  1.0    20     21   26.0    2.0    18     24   2.0
# 3      1    7    13  2.0     2      4   11.0    NaN     8     13   NaN
# 4      1    4     4  NaN     4      3    NaN    NaN     4      5   2.0

# %%
# Get average part of speech counts used in poems of each Text
average_pos_df = pos_counts.groupby(['Text']).mean()

# Round calculations to the nearest whole number
average_pos_df = average_pos_df.round(0)

# Reset index to improve DataFrame readability
average_pos_df = average_pos_df.reset_index()

# Show dataframe
average_pos_df
# Out:
#                                                 Text  ADJ   ADP   ADV  AUX  \
# 0  ﻿After A Hundred Years\n\nAfter a hundred year...  3.0   7.0   1.0  NaN
# 1  ﻿Because I could not stop for Death \n\nHe kin...  2.0  12.0  12.0  4.0
# 2  ﻿Had I not seen the Sun\n\nHad I not seen the ...  1.0   NaN   NaN  4.0
# 3  ﻿I keep my pledge\nI was not called -\nDeath d...  1.0   5.0   3.0  3.0
# 4  ﻿I never saw a Moor\nI never saw a Moor--\nI n...  1.0   3.0   4.0  3.0
#
#    CCONJ   DET  NOUN  NUM  PRON  PROPN  PUNCT  SCONJ  VERB  SPACE  PART
# 0    1.0   7.0  13.0  2.0   2.0    4.0   11.0    NaN   8.0   13.0   NaN
# 1    7.0  15.0  12.0  1.0  20.0   21.0   26.0    2.0  18.0   24.0   2.0
# 2    1.0   4.0   4.0  NaN   4.0    3.0    NaN    NaN   4.0    5.0   2.0
# 3    2.0   1.0   7.0  NaN   8.0    5.0   11.0    NaN   7.0   11.0   2.0
# 4    4.0   7.0   3.0  1.0   6.0    7.0    1.0    3.0   7.0    9.0   NaN

# %%
# Load metadata.
metadata_df = pd.read_csv('metadata.csv')
metadata_df.head()
# Out:
#                                 Title     Author Language           Type
# 0              Had I not seen the Sun  Dickinson  English  modern poetry
# 1                    I keep my pledge  Dickinson  English  modern poetry
# 2                  I never saw a Moor  Dickinson  English  modern poetry
# 3  Because I could not stop for Death  Dickinson  English  modern poetry
# 4               After A Hundred Years  Dickinson  English  modern poetry

# %%
# Rename column from paper ID to Title
poems_df.rename(columns={"Title": "Filename"}, inplace=True)

# %%
# Merge metadata and papers into new DataFrame
# Will only keep rows where both essay and metadata are present
poems_df = metadata_df.merge(poems_df,on='Filename')

# %%
# Print DataFrame
poems_df.head()
# Out:
#                                 Title   Author_x Language_x         Type_x  \
# 0              Had I not seen the Sun  Dickinson    English  modern poetry
# 1                    I keep my pledge  Dickinson    English  modern poetry
# 2                  I never saw a Moor  Dickinson    English  modern poetry
# 3  Because I could not stop for Death  Dickinson    English  modern poetry
# 4               After A Hundred Years  Dickinson    English  modern poetry
#
#     Author_y Language_y         Type_y  \
# 0  Dickinson    English  modern poetry
# 1  Dickinson    English  modern poetry
# 2  Dickinson    English  modern poetry
# 3  Dickinson    English  modern poetry
# 4  Dickinson    English  modern poetry
#
#                                                 Text  \
# 0  ﻿Had I not seen the Sun\n\nHad I not seen the ...
# 1  ﻿I keep my pledge\nI was not called -\nDeath d...
# 2  ﻿I never saw a Moor\nI never saw a Moor--\nI n...
# 3  ﻿Because I could not stop for Death \n\nHe kin...
# 4  ﻿After A Hundred Years\n\nAfter a hundred year...
#
#                                                  Doc  \
# 0  (﻿Had, I, not, seen, the, Sun, \n\n, Had, I, n...
# 1  (﻿I, keep, my, pledge, \n, I, was, not, called...
# 2  (﻿I, never, saw, a, Moor, \n, I, never, saw, a...
# 3  (﻿Because, I, could, not, stop, for, Death, \n...
# 4  (﻿After, A, Hundred, Years, \n\n, After, a, hu...
#
#                                               Tokens  \
# 0  [﻿Had, I, not, seen, the, Sun, \n\n, Had, I, n...
# 1  [﻿I, keep, my, pledge, \n, I, was, not, called...
# 2  [﻿I, never, saw, a, Moor, \n, I, never, saw, a...
# 3  [﻿Because, I, could, not, stop, for, Death, \n...
# 4  [﻿After, A, Hundred, Years, \n\n, After, a, hu...
#
#                                               Lemmas  \
# 0  [﻿had, I, not, see, the, Sun, \n\n, have, I, n...
# 1  [﻿i, keep, my, pledge, \n, I, be, not, call, -...
# 2  [﻿I, never, see, a, Moor, \n, I, never, see, a...
# 3  [﻿because, I, could, not, stop, for, Death, \n...
# 4  [﻿After, a, hundred, Years, \n\n, after, a, hu...
#
#                                                  POS  \
# 0  [(NOUN, NN), (PRON, PRP), (PART, RB), (VERB, V...
# 1  [(NOUN, NN), (VERB, VB), (PRON, PRP$), (NOUN, ...
# 2  [(PROPN, NNP), (ADV, RB), (VERB, VBD), (DET, D...
# 3  [(NOUN, NN), (PRON, PRP), (AUX, MD), (PART, RB...
# 4  [(PUNCT, .), (DET, DT), (NUM, CD), (PROPN, NNP...
#
#                                         Proper_Nouns
# 0                           [Sun, Light, Wilderness]
# 1              [Rose, Bee, Daisy, Bobolink, Blossom]
# 2  [﻿I, Moor, Heather, Billow, God, Checks, given--]
# 3  [Death, Immortality, Civility, School, Fields,...
# 4              [Years, Agony, Motionless, Strangers]

# %%
# Save DataFrame as csv (in Google Drive)
# Use this step only to save  csv to your computer's working directory
poems_df.to_csv('MICUSP_papers_with_spaCy_tags.csv')
